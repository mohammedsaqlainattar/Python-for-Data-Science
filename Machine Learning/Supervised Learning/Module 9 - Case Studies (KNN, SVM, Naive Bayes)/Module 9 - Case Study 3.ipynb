# %% [markdown]
# # Author : Mohammed Saqlain Attar

# %%
import pandas as pd

# %% [markdown]
# ## 1.Load the data from “college.csv” that has attributes collected about private and public colleges for a particular year. We will try to predict the private/public status of the college from other attributes.

# %%
df = pd.read_csv(r'C:\Users\saqla\Desktop\Python Certification for Data Science\Case Studies\Module 9\Datasets\College.csv')
df
# Out:
#     Private   Apps  Accept  Enroll  Top10perc  Top25perc  F.Undergrad  \
# 0       Yes   1660    1232     721         23         52         2885
# 1       Yes   2186    1924     512         16         29         2683
# 2       Yes   1428    1097     336         22         50         1036
# 3       Yes    417     349     137         60         89          510
# 4       Yes    193     146      55         16         44          249
# ..      ...    ...     ...     ...        ...        ...          ...
# 772      No   2197    1515     543          4         26         3089
# 773     Yes   1959    1805     695         24         47         2849
# 774     Yes   2097    1915     695         34         61         2793
# 775     Yes  10705    2453    1317         95         99         5217
# 776     Yes   2989    1855     691         28         63         2988
#
#      P.Undergrad  Outstate  Room.Board  Books  Personal  PhD  Terminal  \
# ...

# %% [markdown]
# ## 2.Use LabelEncoder to encode the target variable in to numerical form and split the data such that 20% of the data is set aside fortesting.

# %% [markdown]
# ### LabelEncoder in sklearn is similar to map or pd.Categorical in Pandas

# %%
from sklearn.preprocessing import LabelEncoder

L_E = LabelEncoder()
df['Private'] = L_E.fit_transform(df['Private'])

# %%
df
# Out:
#      Private   Apps  Accept  Enroll  Top10perc  Top25perc  F.Undergrad  \
# 0          1   1660    1232     721         23         52         2885
# 1          1   2186    1924     512         16         29         2683
# 2          1   1428    1097     336         22         50         1036
# 3          1    417     349     137         60         89          510
# 4          1    193     146      55         16         44          249
# ..       ...    ...     ...     ...        ...        ...          ...
# 772        0   2197    1515     543          4         26         3089
# 773        1   1959    1805     695         24         47         2849
# 774        1   2097    1915     695         34         61         2793
# 775        1  10705    2453    1317         95         99         5217
# 776        1   2989    1855     691         28         63         2988
#
#      P.Undergrad  Outstate  Room.Board  Books  Personal  PhD  Terminal  \
# ...

# %%
X = df.loc[:,'Apps':]
y = df['Private']

from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(X,y, test_size = 0.2, random_state=1)

# %% [markdown]
# ## 3.Fit a linear svm from scikit learn and observe the accuracy.[Hint:Use Linear SVC]

# %%
from sklearn import svm
from sklearn import metrics

# %%
model = svm.LinearSVC()

model.fit(x_train,y_train)

y_pred = model.predict(x_test)

print('Accuracy Score:',metrics.accuracy_score(y_test,y_pred))
# Out:
# Accuracy Score: 0.8012820512820513
# D:\Anaconda\lib\site-packages\sklearn\svm\_base.py:976: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "

# %% [markdown]
# ## 4.Preprocess the data using StandardScalar and fit the same model again and observe the change in accuracy.[Hint: Refer to scikitlearn’s preprocessing methods]

# %%
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()

X_scaled = sc.fit_transform(X)

# %%
X_scaled_df = pd.DataFrame(X_scaled,columns=X.columns)
X_scaled_df
# Out:
#          Apps    Accept    Enroll  Top10perc  Top25perc  F.Undergrad  \
# 0   -0.346882 -0.321205 -0.063509  -0.258583  -0.191827    -0.168116
# 1   -0.210884 -0.038703 -0.288584  -0.655656  -1.353911    -0.209788
# 2   -0.406866 -0.376318 -0.478121  -0.315307  -0.292878    -0.549565
# 3   -0.668261 -0.681682 -0.692427   1.840231   1.677612    -0.658079
# 4   -0.726176 -0.764555 -0.780735  -0.655656  -0.596031    -0.711924
# ..        ...       ...       ...        ...        ...          ...
# 772 -0.208040 -0.205673 -0.255200  -1.336352  -1.505488    -0.126030
# 773 -0.269575 -0.087284 -0.091509  -0.201858  -0.444454    -0.175543
# 774 -0.233895 -0.042377 -0.091509   0.365389   0.262901    -0.187095
# 775  1.991711  0.177256  0.578333   3.825595   2.182866     0.312977
# 776 -0.003268 -0.066872 -0.095816   0.025041   0.363952    -0.146867
#
#      P.Undergrad  Outstate  Room.Board     Books  Personal       PhD  \
# ...

# %%
x_train_sc, x_test_sc, y_train, y_test = train_test_split(X_scaled_df,y, test_size = 0.2, random_state=1)

# %%
model_scaled = svm.LinearSVC()

model_scaled.fit(x_train_sc,y_train)

y_pred_scaled = model.predict(x_test_sc)

print('Accuracy Score:',metrics.accuracy_score(y_test,y_pred_scaled))
# Out:
# Accuracy Score: 0.5641025641025641

# %% [markdown]
# ### After scaling the data, the model is giving worse results because the data is not normally distributed. StandardScaler assumes that the data is normally distributed with each feature.

# %% [markdown]
# ## 5.Use scikit learn’s gridsearch to select the best hyperparameter for a non-linear SVM,identify the model with best score and its parameters.[Hint: Refer to model_selection module of Scikit learn]

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameters = {'C':[0.1,1,10,100,1000],'kernel':('linear', 'poly', 'rbf', 'sigmoid'), 'gamma':['scale','auto']}
# 'gamma':[1,0.1,0.001,0.0001,0.00001,0.000001] or 'gamma':['scale','auto']

svm = svm.SVC(max_iter=10000)

clf = GridSearchCV(estimator=svm,param_grid=parameters,cv=5,n_jobs=-1,return_train_score=False)
clf.fit(x_train,y_train)
print(clf)

print('Best Score:',clf.best_score_)

print('Best Estimator:',clf.best_estimator_)
# Out:
# GridSearchCV(cv=5, estimator=SVC(max_iter=10000), n_jobs=-1,
#              param_grid={'C': [0.1, 1, 10, 100, 1000],
#                          'gamma': ['scale', 'auto'],
#                          'kernel': ('linear', 'poly', 'rbf', 'sigmoid')})
# Best Score: 0.9307354838709678
# Best Estimator: SVC(C=10, max_iter=10000)

# %%
clf.score(x_test,y_test)
# Out:
# 0.9358974358974359

# %%
clf.best_estimator_.gamma
# Out:
# 'scale'

# %%
clf.best_estimator_.kernel
# Out:
# 'rbf'
