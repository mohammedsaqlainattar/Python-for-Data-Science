# %% [markdown]
# # Author : Mohammed Saqlain Attar

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\saqla\Desktop\Python Certification for Data Science\Modules\Module 4\Dataset\BigMartSalesData.csv")
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541869    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541870    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541871    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541872    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541873    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#         UnitPrice  Amount InvoiceDate  Day  Month  Year  CustomerID  \
# ...

# %%
df.dtypes
# Out:
# InvoiceNo       object
# StockCode       object
# Description     object
# Quantity         int64
# UnitPrice      float64
# Amount         float64
# InvoiceDate     object
# Day              int64
# Month            int64
# Year             int64
# CustomerID     float64
# Country         object
# dtype: object

# %%
df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'])

# %%
df.dtypes
# Out:
# InvoiceNo              object
# StockCode              object
# Description            object
# Quantity                int64
# UnitPrice             float64
# Amount                float64
# InvoiceDate    datetime64[ns]
# Day                     int64
# Month                   int64
# Year                    int64
# CustomerID            float64
# Country                object
# dtype: object

# %% [markdown]
# ## 1.Plot Total Sales Per Month for Year 2011.  How the total sales have increased over months in Year 2011. Which month has lowest Sales?

# %%
filt = (df['Year'] == 2011)
data_2011 = df.loc[filt]

# %%
data_2011
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 42479     539993     22386          JUMBO BAG PINK POLKADOT        10
# 42480     539993     21499               BLUE POLKADOT WRAP        25
# 42481     539993     21498              RED RETROSPOT WRAP         25
# 42482     539993     22379         RECYCLING BAG RETROSPOT          5
# 42483     539993     20718        RED RETROSPOT SHOPPER BAG        10
# ...          ...       ...                              ...       ...
# 541869    581587     22613      PACK OF 20 SPACEBOY NAPKINS        12
# 541870    581587     22899     CHILDREN'S APRON DOLLY GIRL          6
# 541871    581587     23254    CHILDRENS CUTLERY DOLLY GIRL          4
# 541872    581587     23255  CHILDRENS CUTLERY CIRCUS PARADE         4
# 541873    581587     22138    BAKING SET 9 PIECE RETROSPOT          3
#
#         UnitPrice  Amount InvoiceDate  Day  Month  Year  CustomerID  \
# ...

# %%
monthly_group = data_2011.filter(items=['Month','Amount']).groupby(['Month'], as_index=False).sum()
monthly_group
# Out:
#     Month       Amount
# 0       1   822669.640
# 1       2   549134.460
# 2       3   752003.310
# 3       4   582318.451
# 4       5   817655.200
# 5       6   832231.670
# 6       7   757108.941
# 7       8   791173.020
# 8       9  1097467.722
# 9      10  1239237.260
# 10     11  1557236.410
# 11     12   843909.020

# %%
plt.style.use('seaborn')

plt.plot(monthly_group['Month'],monthly_group['Amount'], linewidth=2, marker='o', label='Sales')
plt.ticklabel_format(style='plain',axis='y')
plt.title('Total Sales vs Month (2011)')
plt.legend()
plt.xlabel('Month')
plt.ylabel('Amount')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### How the total sales haveincreased over months in Year 2011: Sales were fluctuating from 1st Month till 7th Month. Sales saw an upward trend from 8th Month till 11th Month.
#
# ### Which month has lowest Sales? : February

# %% [markdown]
# ## 2.Plot Total Sales Per Month for Year 2011 as Bar Chart.  Is Bar Chart Better to visualize than Simple Plot?

# %%
plt.style.use('ggplot')

plt.bar(monthly_group['Month'],monthly_group['Amount'], label='Sales')
plt.ticklabel_format(style='plain',axis='y')
plt.title('Total Sales vs Month (2011)')
plt.legend()
plt.xlabel('Month')
plt.ylabel('Amount')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### In my opinion line plots are better to visualize than bar chart in this case since then vartiation is not huge

# %% [markdown]
# # 3.Plot Pie Chart for Year 2011 Country Wise. Which Country contributes highest towards sales?

# %%
country_group = data_2011.filter(items=['Country','Amount']).groupby('Country').sum()
country_group
# Out:
#                             Amount
# Country
# Australia             1.389047e+05
# Austria               9.945680e+03
# Bahrain               7.541400e+02
# Belgium               3.967181e+04
# Brazil                1.143600e+03
# Canada                3.666380e+03
# Channel Islands       2.045106e+04
# Cyprus                1.264365e+04
# Czech Republic        9.457600e+02
# Denmark               1.786104e+04
# EIRE                  2.925945e+05
# European Community    1.308750e+03
# Finland               2.187262e+04
# France                2.123691e+05
# Germany               2.201166e+05
# Greece                4.810520e+03
# Hong Kong             2.126656e+04
# Iceland               3.598210e+03
# Israel                8.135260e+03
# Italy                 1.724747e+04
# Japan                 3.178705e+04
# Lebanon               1.693880e+03
# Malta                 2.945710e+03
# Netherlands           2.774467e+05
# Norway                3.338030e+04
# ...

# %%
plt.style.use('seaborn')
fig, ax = plt.subplots()

ax.pie(country_group['Amount'], labels=country_group.index, wedgeprops = {'edgecolor':'black'});
ax.set_title('Pie Chart')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## The above Chart has too many items for a Pie Chart

# %% [markdown]
# ## Top 5 Countries

# %%
top_5 = country_group.nlargest(5,columns='Amount')
top_5
# Out:
#                       Amount
# Country
# United Kingdom  8.997902e+06
# EIRE            2.925945e+05
# Netherlands     2.774467e+05
# Germany         2.201166e+05
# France          2.123691e+05

# %%
plt.style.use('fivethirtyeight')
fig, ax = plt.subplots()

ax.pie(top_5['Amount'], labels=top_5.index, wedgeprops = {'edgecolor':'black'},explode=[0.2,0,0,0,0], autopct='%1.2f%%', shadow=True)
ax.set_title('Pie Chart')
plt.tight_layout()
plt.show()

# %% [markdown]
# ###  Which Country contributes highest towards sales? : United Kingdom

# %% [markdown]
# ## 4.Plot Scatter Plot for the invoice amounts and see the concentration of amount.  In which range most of the invoice amounts are concentrated

# %%
invoice_amount = data_2011.filter(items=['InvoiceDate','Amount']).groupby('InvoiceDate').sum()
invoice_amount
# Out:
#                Amount
# InvoiceDate
# 2011-01-02   29636.76
# 2011-01-03   27238.21
# 2011-01-04   26943.24
# 2011-01-05    6982.66
# 2011-01-06   21000.18
# ...               ...
# 2011-12-06   12550.26
# 2011-12-07   26633.06
# 2011-12-08   10164.98
# 2011-12-09   30437.35
# 2011-12-10   35015.71
#
# [285 rows x 1 columns]

# %%
plt.style.use('tableau-colorblind10')

plt.scatter(invoice_amount.index,invoice_amount['Amount'], s=100, edgecolor='black', linewidth=1, alpha=0.75)

plt.title('Scatter Plot')
plt.xlabel('InvoiceDate')
plt.ylabel('Amount')
plt.ylim((0,100000))
plt.tight_layout()

plt.show()

# %% [markdown]
# ### In which range most of the invoice amounts are concentrated : Between 20k-40k
